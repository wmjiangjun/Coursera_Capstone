# %%
# !conda install -c conda-forge beautifulsoup4 --yes
# Out:
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
from urllib.request import urlopen
from urllib.request import urlretrieve
from urllib.request import Request
from bs4 import BeautifulSoup
import csv

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
req = Request(url)
html = urlopen(req)
bsObj = BeautifulSoup(html,"lxml")
table = bsObj.findAll("table")[0]
rows = table.findAll("tr")

csvFile = open("C:/temp/postal_codes.csv",'a')
writer = csv.writer(csvFile)

for row in rows:
    csvRow = []
    for column in row.findAll('th'):
        csvRow.append(column.get_text())
    for cell in row.findAll('td'):
        if(cell.get_text()!=""):
            csvRow.append(cell.get_text())
    writer.writerow(csvRow)

# %%
import pandas as pd

postal_data = pd.read_csv("postal_codes.csv")
postal_data.head()
# Out:
#   Postcode           Borough     Neighbourhood\r\n
# 0      M1A      Not assigned      Not assigned\r\n
# 1      M2A      Not assigned      Not assigned\r\n
# 2      M3A        North York         Parkwoods\r\n
# 3      M4A        North York  Victoria Village\r\n
# 4      M5A  Downtown Toronto      Harbourfront\r\n

# %%
postal_data.columns
# Out:
# Index(['Postcode', 'Borough', 'Neighbourhood\r\n'], dtype='object')

# %%
postal_data.rename(columns={'Neighbourhood\r\n':'Neighbourhood'},inplace=True)

# %%
def trip(x):
    return x.replace('\r\n','')

# %%
postal_data['Neighbourhood'] = postal_data['Neighbourhood'].apply(trip)

# %%
postal_data.shape
# Out:
# (836, 3)

# %%
postal_data
# Out:
#     Postcode           Borough                    Neighbourhood
# 0        M1A      Not assigned                     Not assigned
# 1        M2A      Not assigned                     Not assigned
# 2        M3A        North York                        Parkwoods
# 3        M4A        North York                 Victoria Village
# 4        M5A  Downtown Toronto                     Harbourfront
# 5        M5A  Downtown Toronto                      Regent Park
# 6        M6A        North York                 Lawrence Heights
# 7        M6A        North York                   Lawrence Manor
# 8        M7A      Queen's Park                     Not assigned
# 9        M8A      Not assigned                     Not assigned
# 10       M9A         Etobicoke                 Islington Avenue
# 11       M1B       Scarborough                            Rouge
# 12       M1B       Scarborough                          Malvern
# 13       M2B      Not assigned                     Not assigned
# 14       M3B        North York                  Don Mills North
# 15       M4B         East York                 Woodbine Gardens
# 16       M4B         East York                    Parkview Hill
# 17       M5B  Downtown Toronto                          Ryerson
# 18       M5B  Downtown Toronto                  Garden District
# 19       M6B        North York                        Glencairn
# 20       M7B      Not assigned                     Not assigned
# 21       M8B      Not assigned                     Not assigned
# 22       M9B         Etobicoke                       Cloverdale
# 23       M9B         Etobicoke                        Islington
# 24       M9B         Etobicoke                     Martin Grove
# 25       M9B         Etobicoke                 Princess Gardens
# 26       M9B         Etobicoke                  West Deane Park
# 27       M1C       Scarborough                   Highland Creek
# 28       M1C       Scarborough                       Rouge Hill
# 29       M1C       Scarborough                       Port Union
# ..       ...               ...                              ...
# 806      M7V      Not assigned                     Not assigned
# 807      M8V         Etobicoke                Humber Bay Shores
# 808      M8V         Etobicoke                     Mimico South
# 809      M8V         Etobicoke                      New Toronto
# 810      M9V         Etobicoke                   Albion Gardens
# 811      M9V         Etobicoke                 Beaumond Heights
# 812      M9V         Etobicoke                       Humbergate
# 813      M9V         Etobicoke                        Jamestown
# 814      M9V         Etobicoke                      Mount Olive
# 815      M9V         Etobicoke                      Silverstone
# 816      M9V         Etobicoke                    South Steeles
# 817      M9V         Etobicoke                      Thistletown
# 818      M1W       Scarborough                  L'Amoreaux West
# 819      M1W       Scarborough                     Steeles West
# 820      M2W      Not assigned                     Not assigned
# 821      M3W      Not assigned                     Not assigned
# 822      M4W  Downtown Toronto                         Rosedale
# 823      M5W  Downtown Toronto  Stn A PO Boxes 25 The Esplanade
# 824      M6W      Not assigned                     Not assigned
# 825      M7W      Not assigned                     Not assigned
# 826      M8W         Etobicoke                        Alderwood
# 827      M8W         Etobicoke                      Long Branch
# 828      M9W         Etobicoke                        Northwest
# 829      M1X       Scarborough                      Upper Rouge
# 830      M2X      Not assigned                     Not assigned
# 831      M3X      Not assigned                     Not assigned
# 832      M4X  Downtown Toronto                      Cabbagetown
# 833      M4X  Downtown Toronto                   St. James Town
# 834      M5X  Downtown Toronto             First Canadian Place
# 835      M5X  Downtown Toronto                 Underground city
#
# [836 rows x 3 columns]
